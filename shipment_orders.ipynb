# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("orders_data.csv")
data
# Out:
#       Order Id  Order Date       Ship Mode    Segment        Country  \
# 0            1  01-03-2023    Second Class   Consumer  United States
# 1            2  15-08-2023    Second Class   Consumer  United States
# 2            3  10-01-2023    Second Class  Corporate  United States
# 3            4  18-06-2022  Standard Class   Consumer  United States
# 4            5  13-07-2022  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  18-02-2023    Second Class   Consumer  United States
# 9990      9991  17-03-2023  Standard Class   Consumer  United States
# 9991      9992  07-08-2022  Standard Class   Consumer  United States
# 9992      9993  19-11-2022  Standard Class   Consumer  United States
# 9993      9994  17-07-2022    Second Class   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# ...

# %%
data.head(5)
# Out:
#    Order Id  Order Date       Ship Mode    Segment        Country  \
# 0         1  01-03-2023    Second Class   Consumer  United States
# 1         2  15-08-2023    Second Class   Consumer  United States
# 2         3  10-01-2023    Second Class  Corporate  United States
# 3         4  18-06-2022  Standard Class   Consumer  United States
# 4         5  13-07-2022  Standard Class   Consumer  United States
#
#               City       State  Postal Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub Category       Product Id  cost price  List Price  Quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
data.shape
# Out:
# (9994, 16)

# %%
data.describe()
# Out:
#           Order Id   Postal Code    cost price    List Price     Quantity  \
# count  9994.000000   9994.000000   9994.000000   9994.000000  9994.000000
# mean   4997.500000  55190.379428    201.189714    229.756854     3.789574
# std    2885.163629  32063.693350    537.743203    623.245839     2.225110
# min       1.000000   1040.000000      0.000000      0.000000     1.000000
# 25%    2499.250000  23223.000000     20.000000     20.000000     2.000000
# 50%    4997.500000  56430.500000     50.000000     50.000000     3.000000
# 75%    7495.750000  90008.000000    180.000000    210.000000     5.000000
# max    9994.000000  99301.000000  18110.000000  22640.000000    14.000000
#
#        Discount Percent
# count       9994.000000
# mean           3.484090
# std            1.114211
# min            2.000000
# 25%            2.000000
# 50%            3.000000
# 75%            4.000000
# max            5.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order Id          9994 non-null   int64
#  1   Order Date        9994 non-null   object
#  2   Ship Mode         9993 non-null   object
#  3   Segment           9994 non-null   object
#  4   Country           9994 non-null   object
#  5   City              9994 non-null   object
#  6   State             9994 non-null   object
#  7   Postal Code       9994 non-null   int64
#  8   Region            9994 non-null   object
#  9   Category          9994 non-null   object
#  10  Sub Category      9994 non-null   object
#  11  Product Id        9994 non-null   object
#  12  cost price        9994 non-null   int64
#  13  List Price        9994 non-null   int64
#  14  Quantity          9994 non-null   int64
#  15  Discount Percent  9994 non-null   int64
# dtypes: int64(6), object(10)
# ...

# %% [markdown]
# Order date is in object, need to convert into date datatype

# %%
data['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'Not Available', 'unknown',
#        'First Class', nan, 'Same Day'], dtype=object)

# %% [markdown]
# In ship mode column has values like 'Not Available', 'unknown'. so reading data from file, we can handle them as NA values

# %%
df1 = pd.read_csv("orders_data.csv", na_values = ['Not Available', 'unknown'])
df1['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', nan, 'First Class', 'Same Day'],
#       dtype=object)

# %%
df1['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', nan, 'First Class', 'Same Day'],
#       dtype=object)

# %% [markdown]
# Derive New Columns discount, sale price and profit for each unit

# %%
df1.head(5)
# Out:
#    Order Id  Order Date       Ship Mode    Segment        Country  \
# 0         1  01-03-2023    Second Class   Consumer  United States
# 1         2  15-08-2023    Second Class   Consumer  United States
# 2         3  10-01-2023    Second Class  Corporate  United States
# 3         4  18-06-2022  Standard Class   Consumer  United States
# 4         5  13-07-2022  Standard Class   Consumer  United States
#
#               City       State  Postal Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub Category       Product Id  cost price  List Price  Quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
# Selling Price Per Unit

df1['Selling Price'] = df1['List Price'] * (1 -  df1['Discount Percent']/100)
df1['Selling Price']
# Out:
# 0       254.8
# 1       708.1
# 2         9.5
# 3       940.8
# 4        19.0
#         ...
# 9989     28.8
# 9990     86.4
# 9991    254.8
# 9992     29.1
# 9993    232.8
# Name: Selling Price, Length: 9994, dtype: float64

# %%
df1.head(2)
# Out:
#    Order Id  Order Date     Ship Mode   Segment        Country       City  \
# 0         1  01-03-2023  Second Class  Consumer  United States  Henderson
# 1         2  15-08-2023  Second Class  Consumer  United States  Henderson
#
#       State  Postal Code Region   Category Sub Category       Product Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    cost price  List Price  Quantity  Discount Percent  Selling Price
# 0         240         260         2                 2          254.8
# 1         600         730         3                 3          708.1

# %%
# Profit Per Unit

df1['Profit'] = (df1['Selling Price'] - df1['cost price'])
df1['Profit']
# Out:
# 0        14.8
# 1       108.1
# 2        -0.5
# 3       160.8
# 4        -1.0
#         ...
# 9989     -1.2
# 9990     16.4
# 9991     34.8
# 9992     -0.9
# 9993     22.8
# Name: Profit, Length: 9994, dtype: float64

# %%
df1.head(2)
# Out:
#    Order Id  Order Date     Ship Mode   Segment        Country       City  \
# 0         1  01-03-2023  Second Class  Consumer  United States  Henderson
# 1         2  15-08-2023  Second Class  Consumer  United States  Henderson
#
#       State  Postal Code Region   Category Sub Category       Product Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    cost price  List Price  Quantity  Discount Percent  Selling Price  Profit
# 0         240         260         2                 2          254.8    14.8
# 1         600         730         3                 3          708.1   108.1

# %%
# rename columns

df1.rename(columns={'Order Id': 'Order_Id', 'Order Date':'Order_Date', 'Ship Mode':'Ship_Mode', 'Postal Code':'Postal_Code', 'Sub Category':'Sub_Category', 'Product Id':'Product_Id', 'cost price':'Cost_Price', 'List Price':'List_Price', 'Discount Percent':'Discount_Percent', 'Profit' : 'Unit_Profit', 'Selling Price' : 'Unit_Selling_Price'}, inplace= True)
df1.head()
# Out:
#    Order_Id  Order_Date       Ship_Mode    Segment        Country  \
# 0         1  01-03-2023    Second Class   Consumer  United States
# 1         2  15-08-2023    Second Class   Consumer  United States
# 2         3  10-01-2023    Second Class  Corporate  United States
# 3         4  18-06-2022  Standard Class   Consumer  United States
# 4         5  13-07-2022  Standard Class   Consumer  United States
#
#               City       State  Postal_Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub_Category       Product_Id  Cost_Price  List_Price  Quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
df1.dtypes
# Out:
# Order_Id                int64
# Order_Date             object
# Ship_Mode              object
# Segment                object
# Country                object
# City                   object
# State                  object
# Postal_Code             int64
# Region                 object
# Category               object
# Sub_Category           object
# Product_Id             object
# Cost_Price              int64
# List_Price              int64
# Quantity                int64
# Discount_Percent        int64
# Unit_Selling_Price    float64
# Unit_Profit           float64
# dtype: object

# %% [markdown]
# changing datatype of order date column from object to datetime

# %%
df1.head(2)
# Out:
#    Order_Id  Order_Date     Ship_Mode   Segment        Country       City  \
# 0         1  01-03-2023  Second Class  Consumer  United States  Henderson
# 1         2  15-08-2023  Second Class  Consumer  United States  Henderson
#
#       State  Postal_Code Region   Category Sub_Category       Product_Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Cost_Price  List_Price  Quantity  Discount_Percent  Unit_Selling_Price  \
# 0         240         260         2                 2               254.8
# 1         600         730         3                 3               708.1
#
#    Unit_Profit
# 0         14.8
# 1        108.1

# %%
df1['Order_Date'] = pd.to_datetime(df1['Order_Date'], format='%d-%m-%Y')

# %%
df1.dtypes
# Out:
# Order_Id                       int64
# Order_Date            datetime64[ns]
# Ship_Mode                     object
# Segment                       object
# Country                       object
# City                          object
# State                         object
# Postal_Code                    int64
# Region                        object
# Category                      object
# Sub_Category                  object
# Product_Id                    object
# Cost_Price                     int64
# List_Price                     int64
# Quantity                       int64
# Discount_Percent               int64
# Unit_Selling_Price           float64
# Unit_Profit                  float64
# dtype: object

# %%
df1.head()
# Out:
#    Order_Id Order_Date       Ship_Mode    Segment        Country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
#
#               City       State  Postal_Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub_Category       Product_Id  Cost_Price  List_Price  Quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %% [markdown]
# Dropping few columns (cost price, list price, discount percent)

# %%
df1.drop(columns= ['Cost_Price', 'List_Price', 'Discount_Percent'], inplace=True)

# %%
df1.head(2)
# Out:
#    Order_Id Order_Date     Ship_Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal_Code Region   Category Sub_Category       Product_Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit
# 0         2               254.8         14.8
# 1         3               708.1        108.1

# %%
# Total Profit

df1['Total_Profit'] = df1['Quantity'] * df1['Unit_Profit']

# %%
df1.head()
# Out:
#    Order_Id Order_Date       Ship_Mode    Segment        Country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
#
#               City       State  Postal_Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub_Category       Product_Id  Quantity  Unit_Selling_Price  Unit_Profit  \
# 0    Bookcases  FUR-BO-10001798         2               254.8         14.8
# ...

# %%
print(df1.isnull().sum())
# Out:
# Order_Id              0
# Order_Date            0
# Ship_Mode             6
# Segment               0
# Country               0
# City                  0
# State                 0
# Postal_Code           0
# Region                0
# Category              0
# Sub_Category          0
# Product_Id            0
# Quantity              0
# Unit_Selling_Price    0
# Unit_Profit           0
# Total_Profit          0
# dtype: int64

# %% [markdown]
# # Find the highest profit generating products

# %%
df1.groupby('Product_Id')

# %%
df1.groupby('Product_Id').sum(['Total_Profit'])
# Out:
#                  Order_Id  Postal_Code  Quantity  Unit_Selling_Price  \
# Product_Id
# FUR-BO-10000112      3513        60653         9               805.1
# FUR-BO-10000330     13658       256733        10              1036.4
# FUR-BO-10000362     18886       184360        14              2089.4
# FUR-BO-10000468     35749       357215        21               706.1
# FUR-BO-10000711      9310       120635        12               830.9
# ...                   ...          ...       ...                 ...
# TEC-PH-10004912     21739       166396        11               493.8
# TEC-PH-10004922     31470       296048        19              1037.3
# TEC-PH-10004924     13937       105326         8                48.2
# TEC-PH-10004959      5191        83105         4               328.8
# TEC-PH-10004977     49957       473928        32              5099.0
#
#                  Unit_Profit  Total_Profit
# Product_Id
# FUR-BO-10000112         45.1         405.9
# ...

# %%
df1.groupby('Product_Id').sum(['Total_Profit']).sort_values(by = ['Total_Profit'], ascending = False)
# Out:
#                  Order_Id  Postal_Code  Quantity  Unit_Selling_Price  \
# Product_Id
# TEC-CO-10004722     28222       194875        20             59514.0
# TEC-MA-10002412      2698        32216         6             21734.4
# OFF-BI-10000545     57937       302599        48             18249.0
# TEC-CO-10001449     41444       428939        38             18151.2
# FUR-CH-10002024     44560       448062        39             21096.2
# ...                   ...          ...       ...                 ...
# OFF-BI-10003712     46354       562879        45               124.7
# OFF-AR-10003631     20973       277819        30               106.4
# OFF-PA-10000143     38761       389204        29               153.8
# OFF-BI-10002799     32515       368281        40               114.2
# OFF-FA-10002280     54151       608473        47               251.8
#
#                  Unit_Profit  Total_Profit
# Product_Id
# TEC-CO-10004722       5644.0       24816.0
# ...

# %%
df1.groupby('Product_Id').sum(['Total_Profit']).sort_values(by = ['Total_Profit'], ascending = False).reset_index()
# Out:
#            Product_Id  Order_Id  Postal_Code  Quantity  Unit_Selling_Price  \
# 0     TEC-CO-10004722     28222       194875        20             59514.0
# 1     TEC-MA-10002412      2698        32216         6             21734.4
# 2     OFF-BI-10000545     57937       302599        48             18249.0
# 3     TEC-CO-10001449     41444       428939        38             18151.2
# 4     FUR-CH-10002024     44560       448062        39             21096.2
# ...               ...       ...          ...       ...                 ...
# 1857  OFF-BI-10003712     46354       562879        45               124.7
# 1858  OFF-AR-10003631     20973       277819        30               106.4
# 1859  OFF-PA-10000143     38761       389204        29               153.8
# 1860  OFF-BI-10002799     32515       368281        40               114.2
# 1861  OFF-FA-10002280     54151       608473        47               251.8
#
#       Unit_Profit  Total_Profit
# 0          5644.0       24816.0
# ...

# %%
df1.groupby('Product_Id').sum(['Total_Profit']).sort_values(by = ['Total_Profit'], ascending = False).reset_index()['Total_Profit'].head(10)
# Out:
# 0    24816.0
# 1    21746.4
# 2    17867.7
# 3    15948.0
# 4    13930.7
# 5    12792.9
# 6    11481.9
# 7    10102.3
# 8    10015.1
# 9     9989.0
# Name: Total_Profit, dtype: float64

# %%
df1.groupby('Product_Id').sum(['Total_Profit']).sort_values(by = ['Total_Profit'], ascending = False).reset_index()[['Product_Id', 'Total_Profit']].head(10)
# Out:
#         Product_Id  Total_Profit
# 0  TEC-CO-10004722       24816.0
# 1  TEC-MA-10002412       21746.4
# 2  OFF-BI-10000545       17867.7
# 3  TEC-CO-10001449       15948.0
# 4  FUR-CH-10002024       13930.7
# 5  OFF-BI-10003527       12792.9
# 6  TEC-PH-10001459       11481.9
# 7  TEC-MA-10000822       10102.3
# 8  FUR-TA-10000198       10015.1
# 9  TEC-MA-10001047        9989.0

# %% [markdown]
# Create a column for Total Sales value of each order

# %%
df1['Quantity']
# Out:
# 0       2
# 1       3
# 2       2
# 3       5
# 4       2
#        ..
# 9989    3
# 9990    2
# 9991    2
# 9992    4
# 9993    2
# Name: Quantity, Length: 9994, dtype: int64

# %%
df1['Unit_Selling_Price']
# Out:
# 0       254.8
# 1       708.1
# 2         9.5
# 3       940.8
# 4        19.0
#         ...
# 9989     28.8
# 9990     86.4
# 9991    254.8
# 9992     29.1
# 9993    232.8
# Name: Unit_Selling_Price, Length: 9994, dtype: float64

# %%
# calculate the total selling price and profits for all orders

df1['Total_Sales'] = df1['Unit_Selling_Price'] * df1['Quantity']
df1.head(2)
# Out:
#    Order_Id Order_Date     Ship_Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal_Code Region   Category Sub_Category       Product_Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total_Profit  Total_Sales
# 0         2               254.8         14.8          29.6        509.6
# 1         3               708.1        108.1         324.3       2124.3

# %% [markdown]
# # List all distinct cities where orders have been shipped

# %%
df1.head(2)
# Out:
#    Order_Id Order_Date     Ship_Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal_Code Region   Category Sub_Category       Product_Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total_Profit  Total_Sales
# 0         2               254.8         14.8          29.6        509.6
# 1         3               708.1        108.1         324.3       2124.3

# %%
df1['City'].unique()
# Out:
# array(['Henderson', 'Los Angeles', 'Fort Lauderdale', 'Concord',
#        'Seattle', 'Fort Worth', 'Madison', 'West Jordan', 'San Francisco',
#        'Fremont', 'Philadelphia', 'Orem', 'Houston', 'Richardson',
#        'Naperville', 'Melbourne', 'Eagan', 'Westland', 'Dover',
#        'New Albany', 'New York City', 'Troy', 'Chicago', 'Gilbert',
#        'Springfield', 'Jackson', 'Memphis', 'Decatur', 'Durham',
#        'Columbia', 'Rochester', 'Minneapolis', 'Portland', 'Saint Paul',
#        'Aurora', 'Charlotte', 'Orland Park', 'Urbandale', 'Columbus',
#        'Bristol', 'Wilmington', 'Bloomington', 'Phoenix', 'Roseville',
#        'Independence', 'Pasadena', 'Newark', 'Franklin', 'Scottsdale',
#        'San Jose', 'Edmond', 'Carlsbad', 'San Antonio', 'Monroe',
#        'Fairfield', 'Grand Prairie', 'Redlands', 'Hamilton', 'Westfield',
#        'Akron', 'Denver', 'Dallas', 'Whittier', 'Saginaw', 'Medina',
#        'Dublin', 'Detroit', 'Tampa', 'Santa Clara', 'Lakeville',
# ...

# %%
df1['City'].nunique()
# Out:
# 531

# %% [markdown]
# Find all orders from the 'Technology' category that were shipped using 'Second Class' ship mode, ordered by order date

# %%
df1.head(2)
# Out:
#    Order_Id Order_Date     Ship_Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal_Code Region   Category Sub_Category       Product_Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total_Profit  Total_Sales
# 0         2               254.8         14.8          29.6        509.6
# 1         3               708.1        108.1         324.3       2124.3

# %%
df1[df1['Category'] == 'Technology']
# Out:
#       Order_Id Order_Date       Ship_Mode    Segment        Country  \
# 7            8 2022-01-25  Standard Class   Consumer  United States
# 11          12 2023-12-25             NaN   Consumer  United States
# 19          20 2022-01-11    Second Class   Consumer  United States
# 26          27 2022-02-08    Second Class   Consumer  United States
# 35          36 2022-10-30     First Class  Corporate  United States
# ...        ...        ...             ...        ...            ...
# 9983      9984 2022-09-14  Standard Class   Consumer  United States
# 9986      9987 2022-11-30  Standard Class   Consumer  United States
# 9987      9988 2023-04-01  Standard Class  Corporate  United States
# 9988      9989 2022-11-17  Standard Class  Corporate  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
#
#                City       State  Postal_Code   Region    Category  \
# 7       Los Angeles  California        90032     West  Technology
# ...

# %%
df1[df1['Ship_Mode'] == 'Second Class']
# Out:
#       Order_Id Order_Date     Ship_Mode    Segment        Country  \
# 0            1 2023-03-01  Second Class   Consumer  United States
# 1            2 2023-08-15  Second Class   Consumer  United States
# 2            3 2023-01-10  Second Class  Corporate  United States
# 17          18 2023-08-04  Second Class   Consumer  United States
# 18          19 2022-01-23  Second Class   Consumer  United States
# ...        ...        ...           ...        ...            ...
# 9965      9966 2022-12-31  Second Class  Corporate  United States
# 9966      9967 2022-02-21  Second Class  Corporate  United States
# 9980      9981 2023-06-26  Second Class   Consumer  United States
# 9989      9990 2023-02-18  Second Class   Consumer  United States
# 9993      9994 2022-07-17  Second Class   Consumer  United States
#
#                City       State  Postal_Code Region         Category  \
# 0         Henderson    Kentucky        42420  South        Furniture
# ...

# %%
df1[(df1['Category'] == 'Technology') & (df1['Ship_Mode'] == 'Second Class')]
# Out:
#       Order_Id Order_Date     Ship_Mode      Segment        Country  \
# 19          20 2022-01-11  Second Class     Consumer  United States
# 26          27 2022-02-08  Second Class     Consumer  United States
# 161        162 2023-11-27  Second Class     Consumer  United States
# 181        182 2022-06-25  Second Class    Corporate  United States
# 182        183 2022-01-10  Second Class  Home Office  United States
# ...        ...        ...           ...          ...            ...
# 9891      9892 2023-05-21  Second Class    Corporate  United States
# 9892      9893 2023-01-02  Second Class    Corporate  United States
# 9949      9950 2022-01-07  Second Class    Corporate  United States
# 9950      9951 2022-03-19  Second Class    Corporate  United States
# 9960      9961 2023-02-26  Second Class  Home Office  United States
#
#                City         State  Postal_Code   Region    Category  \
# 19    San Francisco    California        94109     West  Technology
# ...

# %%
df1.head(1)
# Out:
#    Order_Id Order_Date     Ship_Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
#
#       State  Postal_Code Region   Category Sub_Category       Product_Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total_Profit  Total_Sales
# 0         2               254.8         14.8          29.6        509.6

# %% [markdown]
# Find the average of total sales

# %%
np.mean(df1['Total_Sales'])
# Out:
# np.float64(1108.5979787872725)

# %%
# mean_total_sales = round(np.mean(df1['Total_Sales']), 2)
# mean_total_sales = float(mean_total_sales)
# mean_total_sales

# %% [markdown]
# Find the city with the highest total quantity of products ordered

# %%
df1.head(2)
# Out:
#    Order_Id Order_Date     Ship_Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal_Code Region   Category Sub_Category       Product_Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total_Profit  Total_Sales
# 0         2               254.8         14.8          29.6        509.6
# 1         3               708.1        108.1         324.3       2124.3

# %%
df1.groupby(['City'])

# %%
df1.groupby('City').sum('Quantity')
# Out:
#              Order_Id  Postal_Code  Quantity  Unit_Selling_Price  Unit_Profit  \
# City
# Aberdeen         9261        57401         3                28.8         -1.2
# Abilene          6990        79605         2                 0.0          0.0
# Akron           97234       930552        65              2650.9        290.9
# Albuquerque     67175      1219470        65              2158.1        208.1
# Alexandria      47898       356864        84              5264.8        294.8
# ...               ...          ...       ...                 ...          ...
# Woonsocket      19448        11580        15               194.0          4.0
# Yonkers         74122       160515        57              7326.5        566.5
# York            23392        87015        19               790.9         60.9
# Yucaipa          3348        92399         5                49.0          9.0
# Yuma            27473       341456        22               812.9         42.9
#
# ...

# %%
df1.groupby('City').sum('Unit_Selling_Price')['Quantity'].reset_index().sort_values(by = ['Quantity'], ascending = False)
# Out:
#               City  Quantity
# 329  New York City      3417
# 266    Los Angeles      2879
# 374   Philadelphia      1981
# 438  San Francisco      1935
# 452        Seattle      1590
# ..             ...       ...
# 257    Lindenhurst         1
# 221        Jupiter         1
# 213      Iowa City         1
# 386    Port Orange         1
# 140         Elyria         1
#
# [531 rows x 2 columns]

# %%
# df1[df1['Order_Id'] == 6489]

# %% [markdown]
# Rank orders in each region by quantity in descending order

# %%
df1[['Order_Id', 'Region', 'Quantity']].sort_values(by = ['Region', 'Quantity'], ascending = [True, False])
# Out:
#       Order_Id   Region  Quantity
# 660        661  Central        14
# 1045      1046  Central        14
# 7387      7388  Central        14
# 8074      8075  Central        14
# 9515      9516  Central        14
# ...        ...      ...       ...
# 9752      9753     West         1
# 9838      9839     West         1
# 9902      9903     West         1
# 9953      9954     West         1
# 9986      9987     West         1
#
# [9994 rows x 3 columns]

# %% [markdown]
# List all orders placed in the first quarter of any year (January to March), including the total cost of these orders

# %%
df1.head(2)
# Out:
#    Order_Id Order_Date     Ship_Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal_Code Region   Category Sub_Category       Product_Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total_Profit  Total_Sales
# 0         2               254.8         14.8          29.6        509.6
# 1         3               708.1        108.1         324.3       2124.3

# %%
df1['Order_Date'].dt.month
# Out:
# 0        3
# 1        8
# 2        1
# 3        6
# 4        7
#         ..
# 9989     2
# 9990     3
# 9991     8
# 9992    11
# 9993     7
# Name: Order_Date, Length: 9994, dtype: int32

# %%
df1['Month'] = df1['Order_Date'].dt.month
df1.head(2)
# Out:
#    Order_Id Order_Date     Ship_Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal_Code Region   Category Sub_Category       Product_Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total_Profit  Total_Sales  Month
# 0         2               254.8         14.8          29.6        509.6      3
# 1         3               708.1        108.1         324.3       2124.3      8

# %%
df1[df1['Month'].isin([1,2,3])].head(10)
# Out:
#     Order_Id Order_Date       Ship_Mode    Segment        Country  \
# 0          1 2023-03-01    Second Class   Consumer  United States
# 2          3 2023-01-10    Second Class  Corporate  United States
# 5          6 2022-03-13             NaN   Consumer  United States
# 7          8 2022-01-25  Standard Class   Consumer  United States
# 8          9 2023-03-23             NaN   Consumer  United States
# 10        11 2023-03-31             NaN   Consumer  United States
# 12        13 2022-02-11  Standard Class   Consumer  United States
# 16        17 2022-02-04  Standard Class   Consumer  United States
# 18        19 2022-01-23    Second Class   Consumer  United States
# 19        20 2022-01-11    Second Class   Consumer  United States
#
#              City           State  Postal_Code   Region         Category  \
# 0       Henderson        Kentucky        42420    South        Furniture
# 2     Los Angeles      California        90036     West  Office Supplies
# ...

# %%
# ALternate

# df1['Quarter'] = df1['Order_Date'].dt.quarter
# df1.head(2)

# df1[df1['Quarter'] == 1]

# %%
# df1[df1['Order_Date'].dt.month.isin([1, 2, 3])]

# %%
df1['Order_Year'] = df1['Order_Date'].dt.year
df1.head(2)
# Out:
#    Order_Id Order_Date     Ship_Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal_Code Region   Category Sub_Category       Product_Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total_Profit  Total_Sales  \
# 0         2               254.8         14.8          29.6        509.6
# 1         3               708.1        108.1         324.3       2124.3
#
#    Month  Order_Year
# 0      3        2023
# 1      8        2023

# %%
df1['Quarter'] = df1['Order_Date'].dt.quarter
df1.head(2)
# Out:
#    Order_Id Order_Date     Ship_Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal_Code Region   Category Sub_Category       Product_Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total_Profit  Total_Sales  \
# 0         2               254.8         14.8          29.6        509.6
# 1         3               708.1        108.1         324.3       2124.3
#
#    Month  Order_Year  Quarter
# 0      3        2023        1
# 1      8        2023        3

# %%
temp_df = df1.groupby(['Order_Year', 'Quarter']).sum('Total_Sales')['Total_Sales'].reset_index()
temp_df
# Out:
#    Order_Year  Quarter  Total_Sales
# 0        2022        1    1275547.6
# 1        2022        2    1355326.7
# 2        2022        3    1343727.8
# 3        2022        4    1500939.2
# 4        2023        1    1559456.2
# 5        2023        2    1282878.4
# 6        2023        3    1308164.5
# 7        2023        4    1453287.8

# %%
temp_df[temp_df['Quarter'] == 1]
# Out:
#    Order_Year  Quarter  Total_Sales
# 0        2022        1    1275547.6
# 4        2023        1    1559456.2

# %% [markdown]
# Find top 10 highest profit generating products

# %%
df1.head(2)
# Out:
#    Order_Id Order_Date     Ship_Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal_Code Region   Category Sub_Category       Product_Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total_Profit  Total_Sales  \
# 0         2               254.8         14.8          29.6        509.6
# 1         3               708.1        108.1         324.3       2124.3
#
#    Month  Order_Year  Quarter
# 0      3        2023        1
# 1      8        2023        3

# %%
df1.groupby('Product_Id').sum(['Total_Profit'])['Total_Profit'].reset_index().sort_values(by = 'Total_Profit', ascending = False).head(10)
# Out:
#            Product_Id  Total_Profit
# 1614  TEC-CO-10004722       24816.0
# 1642  TEC-MA-10002412       21746.4
# 657   OFF-BI-10000545       17867.7
# 1604  TEC-CO-10001449       15948.0
# 80    FUR-CH-10002024       13930.7
# 776   OFF-BI-10003527       12792.9
# 1724  TEC-PH-10001459       11481.9
# 1624  TEC-MA-10000822       10102.3
# 318   FUR-TA-10000198       10015.1
# 1630  TEC-MA-10001047        9989.0

# %% [markdown]
# Find the top 3 highest selling products in each region according to quantity

# %%
df1.groupby(['Region', 'Product_Id']).sum('Quantity')
# Out:
#                          Order_Id  Postal_Code  Quantity  Unit_Selling_Price  \
# Region  Product_Id
# Central FUR-BO-10000112      3513        60653         9               805.1
#         FUR-BO-10000362      1595        61604         3               349.2
#         FUR-BO-10000468      3031        48146         4               180.5
#         FUR-BO-10000711      5221        48234         3               203.7
#         FUR-BO-10000780     16297       229596        17              2223.1
# ...                           ...          ...       ...                 ...
# West    TEC-PH-10004896      1088        94601         3                68.6
#         TEC-PH-10004897      4320        87105         3                19.2
#         TEC-PH-10004908     38344       421143        22              1433.2
#         TEC-PH-10004922     11121       180757         9               459.2
#         TEC-PH-10004977     11216       262951        10              1500.9
#
# ...

# %%
df1.groupby(['Region', 'Product_Id']).sum('Quantity')['Quantity']
# Out:
# Region   Product_Id
# Central  FUR-BO-10000112     9
#          FUR-BO-10000362     3
#          FUR-BO-10000468     4
#          FUR-BO-10000711     3
#          FUR-BO-10000780    17
#                             ..
# West     TEC-PH-10004896     3
#          TEC-PH-10004897     3
#          TEC-PH-10004908    22
#          TEC-PH-10004922     9
#          TEC-PH-10004977    10
# Name: Quantity, Length: 5298, dtype: int64

# %%
df1.groupby(['Region', 'Product_Id']).sum('Quantity')['Quantity'].reset_index()
# Out:
#        Region       Product_Id  Quantity
# 0     Central  FUR-BO-10000112         9
# 1     Central  FUR-BO-10000362         3
# 2     Central  FUR-BO-10000468         4
# 3     Central  FUR-BO-10000711         3
# 4     Central  FUR-BO-10000780        17
# ...       ...              ...       ...
# 5293     West  TEC-PH-10004896         3
# 5294     West  TEC-PH-10004897         3
# 5295     West  TEC-PH-10004908        22
# 5296     West  TEC-PH-10004922         9
# 5297     West  TEC-PH-10004977        10
#
# [5298 rows x 3 columns]

# %%
x = df1.groupby(['Region', 'Product_Id']).sum('Quantity')['Quantity'].reset_index().sort_values(by = ['Region', 'Quantity'], ascending = [True, False]).head(10)
x
# Out:
#        Region       Product_Id  Quantity
# 461   Central  OFF-BI-10000301        34
# 474   Central  OFF-BI-10000756        33
# 470   Central  OFF-BI-10000546        29
# 491   Central  OFF-BI-10001249        29
# 61    Central  FUR-CH-10002304        27
# 299   Central  OFF-AP-10001947        27
# 69    Central  FUR-CH-10002880        26
# 188   Central  FUR-FU-10003724        25
# 589   Central  OFF-BI-10004040        25
# 1140  Central  TEC-AC-10004510        25

# %%
x.groupby('Region').head(2).reset_index()
# Out:
#    index   Region       Product_Id  Quantity
# 0    461  Central  OFF-BI-10000301        34
# 1    474  Central  OFF-BI-10000756        33

# %%
df1.head(2)
# Out:
#    Order_Id Order_Date     Ship_Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal_Code Region   Category Sub_Category       Product_Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total_Profit  Total_Sales  \
# 0         2               254.8         14.8          29.6        509.6
# 1         3               708.1        108.1         324.3       2124.3
#
#    Month  Order_Year  Quarter
# 0      3        2023        1
# 1      8        2023        3

# %% [markdown]
# Total sale in each region

# %%
df1.groupby('Region').sum(['Total_Sales'])
# Out:
#          Order_Id  Postal_Code  Quantity  Unit_Selling_Price  Unit_Profit  \
# Region
# Central  11685963    151786150      8780            483668.6      46378.6
# East     14073919     50171698     10618            654320.0      58220.0
# South     8213295     55875052      6209            378011.5      38011.5
# West     15971838    293739752     12266            699858.6      62558.6
#
#          Total_Profit  Total_Sales  Month  Order_Year  Quarter
# Region
# Central      236121.2    2387881.2  15256     4698281     5875
# East         295773.8    3257983.8  18605     5760082     7169
# South        202743.6    1966053.6  10427     3276428     4026
# West         305289.6    3467409.6  20732     6478034     8023

# %%
df1.groupby('Region').sum(['Total_Sales']).reset_index()
# Out:
#     Region  Order_Id  Postal_Code  Quantity  Unit_Selling_Price  Unit_Profit  \
# 0  Central  11685963    151786150      8780            483668.6      46378.6
# 1     East  14073919     50171698     10618            654320.0      58220.0
# 2    South   8213295     55875052      6209            378011.5      38011.5
# 3     West  15971838    293739752     12266            699858.6      62558.6
#
#    Total_Profit  Total_Sales  Month  Order_Year  Quarter
# 0      236121.2    2387881.2  15256     4698281     5875
# 1      295773.8    3257983.8  18605     5760082     7169
# 2      202743.6    1966053.6  10427     3276428     4026
# 3      305289.6    3467409.6  20732     6478034     8023

# %%
df1.groupby('Region').sum(['Total_Sales'])['Total_Sales']
# Out:
# Region
# Central    2387881.2
# East       3257983.8
# South      1966053.6
# West       3467409.6
# Name: Total_Sales, dtype: float64

# %%
df1.groupby('Region').sum(['Total_Sales'])['Total_Sales'].reset_index()
# Out:
#     Region  Total_Sales
# 0  Central    2387881.2
# 1     East    3257983.8
# 2    South    1966053.6
# 3     West    3467409.6

# %%
df1.groupby('Region').sum(['Total_Sales'])['Total_Sales'].reset_index().sort_values(by = ['Total_Sales'], ascending = False)
# Out:
#     Region  Total_Sales
# 3     West    3467409.6
# 1     East    3257983.8
# 0  Central    2387881.2
# 2    South    1966053.6

# %% [markdown]
# Find top 5 highest selling products in each region according to sales

# %%
df1.groupby(['Region', 'Product_Id']).sum(['Total_Sales'])
# Out:
#                          Order_Id  Postal_Code  Quantity  Unit_Selling_Price  \
# Region  Product_Id
# Central FUR-BO-10000112      3513        60653         9               805.1
#         FUR-BO-10000362      1595        61604         3               349.2
#         FUR-BO-10000468      3031        48146         4               180.5
#         FUR-BO-10000711      5221        48234         3               203.7
#         FUR-BO-10000780     16297       229596        17              2223.1
# ...                           ...          ...       ...                 ...
# West    TEC-PH-10004896      1088        94601         3                68.6
#         TEC-PH-10004897      4320        87105         3                19.2
#         TEC-PH-10004908     38344       421143        22              1433.2
#         TEC-PH-10004922     11121       180757         9               459.2
#         TEC-PH-10004977     11216       262951        10              1500.9
#
# ...

# %%
df1.groupby(['Region', 'Product_Id']).sum(['Total_Sales']).reset_index()
# Out:
#        Region       Product_Id  Order_Id  Postal_Code  Quantity  \
# 0     Central  FUR-BO-10000112      3513        60653         9
# 1     Central  FUR-BO-10000362      1595        61604         3
# 2     Central  FUR-BO-10000468      3031        48146         4
# 3     Central  FUR-BO-10000711      5221        48234         3
# 4     Central  FUR-BO-10000780     16297       229596        17
# ...       ...              ...       ...          ...       ...
# 5293     West  TEC-PH-10004896      1088        94601         3
# 5294     West  TEC-PH-10004897      4320        87105         3
# 5295     West  TEC-PH-10004908     38344       421143        22
# 5296     West  TEC-PH-10004922     11121       180757         9
# 5297     West  TEC-PH-10004977     11216       262951        10
#
#       Unit_Selling_Price  Unit_Profit  Total_Profit  Total_Sales  Month  \
# 0                  805.1         45.1         405.9       7245.9      4
# ...

# %%
x = df1.groupby(['Region', 'Product_Id']).sum(['Total_Sales'])['Total_Sales'].reset_index()
y = x.sort_values(by = ['Region', 'Total_Sales'], ascending = [True, False])
y.groupby('Region').head(5).reset_index()
# Out:
#     index   Region       Product_Id  Total_Sales
# 0     469  Central  OFF-BI-10000545     125827.5
# 1    1166  Central  TEC-CO-10004722      84875.0
# 2    1168  Central  TEC-MA-10000822      77509.8
# 3     488  Central  OFF-BI-10001120      55282.5
# 4     617  Central  OFF-BI-10004995      42210.0
# 5    2556     East  TEC-CO-10004722     106421.0
# 6    2565     East  TEC-MA-10001047      81549.0
# 7    1342     East  FUR-BO-10004834      66364.2
# 8    2548     East  TEC-CO-10001449      60948.0
# 9    1369     East  FUR-CH-10002024      60189.6
# 10   3691    South  TEC-MA-10002412     130406.4
# 11   3719    South  TEC-PH-10001459      73932.1
# 12   2910    South  FUR-TA-10000198      68789.9
# 13   3687    South  TEC-MA-10001127      50499.2
# 14   3192    South  OFF-BI-10003527      32029.4
# 15   5088     West  TEC-AC-10003832      61170.8
# 16   5126     West  TEC-CO-10004722      53760.0
# 17   4964     West  OFF-SU-10000151      53337.9
# ...

# %%
x.sort_values(by = ['Region', 'Total_Sales'], ascending = [True, False])
# Out:
#        Region       Product_Id  Total_Sales
# 469   Central  OFF-BI-10000545     125827.5
# 1166  Central  TEC-CO-10004722      84875.0
# 1168  Central  TEC-MA-10000822      77509.8
# 488   Central  OFF-BI-10001120      55282.5
# 617   Central  OFF-BI-10004995      42210.0
# ...       ...              ...          ...
# 4571     West  OFF-FA-10003472          0.0
# 4581     West  OFF-LA-10000134          0.0
# 4622     West  OFF-LA-10003714          0.0
# 4817     West  OFF-PA-10004000          0.0
# 4854     West  OFF-PA-10004948          0.0
#
# [5298 rows x 3 columns]

# %% [markdown]
# Find month over month growth comparision for 2022 and 2023 sales eg : jan 2022 vs jan 2023

# %%
df1['Month'] = df1['Order_Date'].dt.month
df1['Month']
# Out:
# 0        3
# 1        8
# 2        1
# 3        6
# 4        7
#         ..
# 9989     2
# 9990     3
# 9991     8
# 9992    11
# 9993     7
# Name: Month, Length: 9994, dtype: int32

# %%
df1.head(2)
# Out:
#    Order_Id Order_Date     Ship_Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal_Code Region   Category Sub_Category       Product_Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total_Profit  Total_Sales  \
# 0         2               254.8         14.8          29.6        509.6
# 1         3               708.1        108.1         324.3       2124.3
#
#    Month  Order_Year  Quarter
# 0      3        2023        1
# 1      8        2023        3

# %%
df1.groupby(['Month', 'Order_Year'])

# %%
df1.groupby(['Month', 'Order_Year']).sum('Total_Sales')
# Out:
#                   Order_Id  Postal_Code  Quantity  Unit_Selling_Price  \
# Month Order_Year
# 1     2022         2203269     25254924      1650             94712.5
#       2023         2159265     22745269      1543             88632.6
# 2     2022         1942952     21548462      1511             90091.0
#       2023         1963083     21939004      1574            128124.2
# 3     2022         2001085     20660876      1447             80106.0
#       2023         2204143     23815029      1651             82512.3
# 4     2022         2214787     25361800      1648             95451.6
#       2023         1941539     22098149      1501            111568.6
# 5     2022         2076080     23908332      1639             79448.3
#       2023         2038723     23553002      1561             86447.9
# 6     2022         1967618     21814012      1528             94170.5
#       2023         1864583     20450282      1422             68976.5
# ...

# %%
df1.groupby(['Month', 'Order_Year']).sum('Total_Sales')['Total_Sales']
# Out:
# Month  Order_Year
# 1      2022          437431.3
#        2023          434765.5
# 2      2022          444011.1
#        2023          731638.8
# 3      2022          394105.2
#        2023          393051.9
# 4      2022          476400.9
#        2023          543231.5
# 5      2022          413625.5
#        2023          410707.9
# 6      2022          465300.3
#        2023          328939.0
# 7      2022          375278.4
#        2023          422533.7
# 8      2022          534562.4
#        2023          465010.3
# 9      2022          433887.0
#        2023          420620.5
# 10     2022          601707.8
#        2023          626498.3
# 11     2022          451809.6
#        2023          334940.6
# 12     2022          447421.8
#        2023          491848.9
# Name: Total_Sales, dtype: float64

# %%
total_sales_temp = df1.groupby(['Month', 'Order_Year']).sum('Total_Sales')['Total_Sales'].reset_index()
total_sales_temp
# Out:
#     Month  Order_Year  Total_Sales
# 0       1        2022     437431.3
# 1       1        2023     434765.5
# 2       2        2022     444011.1
# 3       2        2023     731638.8
# 4       3        2022     394105.2
# 5       3        2023     393051.9
# 6       4        2022     476400.9
# 7       4        2023     543231.5
# 8       5        2022     413625.5
# 9       5        2023     410707.9
# 10      6        2022     465300.3
# 11      6        2023     328939.0
# 12      7        2022     375278.4
# 13      7        2023     422533.7
# 14      8        2022     534562.4
# 15      8        2023     465010.3
# 16      9        2022     433887.0
# 17      9        2023     420620.5
# 18     10        2022     601707.8
# 19     10        2023     626498.3
# 20     11        2022     451809.6
# 21     11        2023     334940.6
# 22     12        2022     447421.8
# 23     12        2023     491848.9

# %%
# total_sales_temp1 = df1.groupby(['Month', 'Order_Year']).sum('Total_Sales')[['Total_Sales']].reset_index()
# print(total_sales_temp1.to_string(index=False))

# %%
pivot_table = total_sales_temp.pivot_table(index = 'Month', columns = 'Order_Year', values = 'Total_Sales', aggfunc = 'sum')
pivot_table
# Out:
# Order_Year      2022      2023
# Month
# 1           437431.3  434765.5
# 2           444011.1  731638.8
# 3           394105.2  393051.9
# 4           476400.9  543231.5
# 5           413625.5  410707.9
# 6           465300.3  328939.0
# 7           375278.4  422533.7
# 8           534562.4  465010.3
# 9           433887.0  420620.5
# 10          601707.8  626498.3
# 11          451809.6  334940.6
# 12          447421.8  491848.9

# %%
pivot_table = pivot_table.reset_index()
pivot_table
# Out:
# Order_Year  Month      2022      2023
# 0               1  437431.3  434765.5
# 1               2  444011.1  731638.8
# 2               3  394105.2  393051.9
# 3               4  476400.9  543231.5
# 4               5  413625.5  410707.9
# 5               6  465300.3  328939.0
# 6               7  375278.4  422533.7
# 7               8  534562.4  465010.3
# 8               9  433887.0  420620.5
# 9              10  601707.8  626498.3
# 10             11  451809.6  334940.6
# 11             12  447421.8  491848.9

# %%
pivot_table['YoY_Growth'] = pivot_table[2022] - pivot_table[2023]
pivot_table
# Out:
# Order_Year  Month      2022      2023  YoY_Growth
# 0               1  437431.3  434765.5      2665.8
# 1               2  444011.1  731638.8   -287627.7
# 2               3  394105.2  393051.9      1053.3
# 3               4  476400.9  543231.5    -66830.6
# 4               5  413625.5  410707.9      2917.6
# 5               6  465300.3  328939.0    136361.3
# 6               7  375278.4  422533.7    -47255.3
# 7               8  534562.4  465010.3     69552.1
# 8               9  433887.0  420620.5     13266.5
# 9              10  601707.8  626498.3    -24790.5
# 10             11  451809.6  334940.6    116869.0
# 11             12  447421.8  491848.9    -44427.1

# %%
df1.head(2)
# Out:
#    Order_Id Order_Date     Ship_Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal_Code Region   Category Sub_Category       Product_Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total_Profit  Total_Sales  \
# 0         2               254.8         14.8          29.6        509.6
# 1         3               708.1        108.1         324.3       2124.3
#
#    Month  Order_Year  Quarter
# 0      3        2023        1
# 1      8        2023        3

# %%
df1['Month_Year'] = df1['Order_Date'].dt.strftime('%Y-%m')
df1.head(2)
# Out:
#    Order_Id Order_Date     Ship_Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal_Code Region   Category  ...       Product_Id Quantity  \
# 0  Kentucky        42420  South  Furniture  ...  FUR-BO-10001798        2
# 1  Kentucky        42420  South  Furniture  ...  FUR-CH-10000454        3
#
#    Unit_Selling_Price  Unit_Profit  Total_Profit  Total_Sales  Month  \
# 0               254.8         14.8          29.6        509.6      3
# 1               708.1        108.1         324.3       2124.3      8
#
#    Order_Year  Quarter  Month_Year
# 0        2023        1     2023-03
# 1        2023        3     2023-08
#
# [2 rows x 21 columns]

# %% [markdown]
# For each category which month had highest sales

# %%
df1.head(11).groupby(['Month_Year', 'Category']).sum(['Total_Sales'])['Total_Sales'].reset_index().sort_values(by='Total_Sales', ascending = False)
# Out:
#   Month_Year         Category  Total_Sales
# 6    2023-03        Furniture      15437.9
# 0    2022-01       Technology       5187.0
# 2    2022-06        Furniture       4704.0
# 9    2023-08        Furniture       2124.3
# 8    2023-05  Office Supplies        533.5
# 1    2022-03        Furniture        339.5
# 7    2023-03  Office Supplies         58.8
# 4    2022-12  Office Supplies         38.8
# 3    2022-07  Office Supplies         38.0
# 5    2023-01  Office Supplies         19.0

# %%
temp_b = df1.groupby(['Category', 'Month_Year']).sum(['Total_Sales'])['Total_Sales'].reset_index()
temp_b
# Out:
#       Category Month_Year  Total_Sales
# 0    Furniture    2022-01     170244.5
# 1    Furniture    2022-02     192062.9
# 2    Furniture    2022-03     150128.1
# 3    Furniture    2022-04     162806.9
# 4    Furniture    2022-05     110578.8
# ..         ...        ...          ...
# 67  Technology    2023-08     117665.2
# 68  Technology    2023-09     137873.1
# 69  Technology    2023-10     295586.5
# 70  Technology    2023-11     121226.6
# 71  Technology    2023-12     156836.6
#
# [72 rows x 3 columns]

# %%
temp_c = temp_b.sort_values(by = ['Category', 'Total_Sales'], ascending = [True, False])
temp_c
# Out:
#       Category Month_Year  Total_Sales
# 19   Furniture    2023-08     230523.5
# 9    Furniture    2022-10     229024.8
# 13   Furniture    2023-02     217851.0
# 10   Furniture    2022-11     203673.6
# 1    Furniture    2022-02     192062.9
# ..         ...        ...          ...
# 67  Technology    2023-08     117665.2
# 48  Technology    2022-01     117116.5
# 51  Technology    2022-04     114747.7
# 54  Technology    2022-07     102816.1
# 49  Technology    2022-02      93493.2
#
# [72 rows x 3 columns]

# %%
temp_c.groupby('Category').head(1)
# Out:
#            Category Month_Year  Total_Sales
# 19        Furniture    2023-08     230523.5
# 37  Office Supplies    2023-02     287244.6
# 69       Technology    2023-10     295586.5

# %%
df1.head(2)
# Out:
#    Order_Id Order_Date     Ship_Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal_Code Region   Category  ...       Product_Id Quantity  \
# 0  Kentucky        42420  South  Furniture  ...  FUR-BO-10001798        2
# 1  Kentucky        42420  South  Furniture  ...  FUR-CH-10000454        3
#
#    Unit_Selling_Price  Unit_Profit  Total_Profit  Total_Sales  Month  \
# 0               254.8         14.8          29.6        509.6      3
# 1               708.1        108.1         324.3       2124.3      8
#
#    Order_Year  Quarter  Month_Year
# 0        2023        1     2023-03
# 1        2023        3     2023-08
#
# [2 rows x 21 columns]

# %% [markdown]
# Which sub category had highest growth by profit in 2023 compare to 2022

# %%
temp_m = df1.groupby(['Sub_Category', 'Order_Year']).sum(['Total_Profit'])['Total_Profit'].reset_index()
temp_m
# Out:
#    Sub_Category  Order_Year  Total_Profit
# 0   Accessories        2022       38798.3
# 1   Accessories        2023       40613.7
# 2    Appliances        2022       37088.7
# 3    Appliances        2023       17493.9
# 4           Art        2022        5333.0
# 5           Art        2023        5079.2
# 6       Binders        2022       40812.5
# 7       Binders        2023       57990.3
# 8     Bookcases        2022       25494.7
# 9     Bookcases        2023       25776.1
# 10       Chairs        2022       78672.5
# 11       Chairs        2023       75233.2
# 12      Copiers        2022       42703.1
# 13      Copiers        2023       26561.8
# 14    Envelopes        2022        2607.3
# 15    Envelopes        2023        3502.4
# 16    Fasteners        2022         370.7
# 17    Fasteners        2023          87.9
# 18  Furnishings        2022       22655.3
# 19  Furnishings        2023       16428.4
# 20       Labels        2022        2007.2
# ...

# %%
temp_n = temp_m.pivot_table(index = 'Sub_Category', columns = 'Order_Year', values = 'Total_Profit').reset_index()
temp_n.head()
# Out:
# Order_Year Sub_Category     2022     2023
# 0           Accessories  38798.3  40613.7
# 1            Appliances  37088.7  17493.9
# 2                   Art   5333.0   5079.2
# 3               Binders  40812.5  57990.3
# 4             Bookcases  25494.7  25776.1

# %%
temp_n['diff'] = temp_n[2023] - temp_n[2022]
temp_n.sort_values(by = ['diff'], ascending = False).head(2)
# Out:
# Order_Year Sub_Category     2022     2023     diff
# 11             Machines  34605.5  56939.8  22334.3
# 3               Binders  40812.5  57990.3  17177.8

# %%
df1.head(2)
# Out:
#    Order_Id Order_Date     Ship_Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal_Code Region   Category  ...       Product_Id Quantity  \
# 0  Kentucky        42420  South  Furniture  ...  FUR-BO-10001798        2
# 1  Kentucky        42420  South  Furniture  ...  FUR-CH-10000454        3
#
#    Unit_Selling_Price  Unit_Profit  Total_Profit  Total_Sales  Month  \
# 0               254.8         14.8          29.6        509.6      3
# 1               708.1        108.1         324.3       2124.3      8
#
#    Order_Year  Quarter  Month_Year
# 0        2023        1     2023-03
# 1        2023        3     2023-08
#
# [2 rows x 21 columns]

# %%
# retrive data for a specific index

# postal_code_at_index = df1.loc[0, 'Postal_Code']
# postal_code_at_index
# Out:
# np.int64(42420)

# %%
# check if the postal code at index 0 is equal to 42420

# is_postal_code_42420 = df1.loc[0, 'Postal_Code'] == 42420
# is_postal_code_42420

# %%
# Retrieve the entire row at index 0

# row_at_index_0 = df1.iloc[0]
# row_at_index_0

# %%
# Retrieve the entire row at index 0

# row_at_index_0 = df1.loc[0]
# row_at_index_0

# %% [markdown]
# # Build SQL connection to get data from pandas dataframe into SQL

# %%
#!pip install mysql-connector-python

import sqlalchemy as sal
engine = sal.create_engine('mysql+mysqlconnector://root:1234@localhost:3306/shipments')

conn = engine.connect()

df1.to_sql('orders', con = conn, index = False, if_exists = 'replace') # if already existed = 'append', or 'replace'
# Out:
# 9994

# %% [markdown]
# # Querying Data from MySQL

# %%
try:
    with engine.connect() as conn:
        result = conn.execute(sal.text("select City from orders;"))
        print(result.all())
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# [('Henderson',), ('Henderson',), ('Los Angeles',), ('Fort Lauderdale',), ('Fort Lauderdale',), ('Los Angeles',), ('Los Angeles',), ('Los Angeles',), ('Los Angeles',), ('Los Angeles',), ('Los Angeles',), ('Los Angeles',), ('Concord',), ('Seattle',), ('Fort Worth',), ('Fort Worth',), ('Madison',), ('West Jordan',), ('San Francisco',), ('San Francisco',), ('San Francisco',), ('Fremont',), ('Fremont',), ('Philadelphia',), ('Orem',), ('Los Angeles',), ('Los Angeles',), ('Philadelphia',), ('Philadelphia',), ('Philadelphia',), ('Philadelphia',), ('Philadelphia',), ('Philadelphia',), ('Philadelphia',), ('Houston',), ('Richardson',), ('Richardson',), ('Houston',), ('Houston',), ('Houston',), ('Houston',), ('Naperville',), ('Los Angeles',), ('Melbourne',), ('Eagan',), ('Eagan',), ('Westland',), ('Dover',), ('Dover',), ('New Albany',), ('New Albany',), ('New Albany',), ('New Albany',), ('New York City',), ('New York City',), ('Troy',), ('Troy',), ('Troy',), ('Troy',), ('Troy',), ('Troy',), ('Tr
# ...

# %%
import pandas as pd

try:
    with engine.connect() as conn:
        query = "select Order_Id, cast(sum(Quantity * Unit_Selling_Price) as decimal(10, 2)) as 'Total_Selling_Price', cast(sum(Quantity * Unit_Profit) as decimal(10, 2)) as 'Total_Profitt' from  orders group by Order_Id order by Total_Profitt desc;";
        # Load the query result into a DataFrame
        df = pd.read_sql_query(query, conn)
        print(df)
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
#       Order_Id  Total_Selling_Price  Total_Profitt
# 0         2698             130406.4        21746.4
# 1         6827              84875.0        14875.0
# 2         9040             122141.5        12811.5
# 3         4278              61789.0         8309.0
# 4          166              62668.8         7868.8
# ...        ...                  ...            ...
# 9989      7930               1710.0          -30.0
# 9990      4580                739.2          -30.8
# 9991      2568              22828.5          -31.5
# 9992      9122                598.5          -31.5
# 9993      3669                960.0          -40.0
#
# [9994 rows x 3 columns]

# %% [markdown]
# Result the Query to DataFrame and reading to CSV file

# %%
import pandas as pd

try:
    with engine.connect() as conn:
        query = "select Order_Id, cast(sum(Quantity * Unit_Selling_Price) as decimal(10, 2)) as 'Total_Selling_Price', cast(sum(Quantity * Unit_Profit) as decimal(10, 2)) as 'Total_Profitt' from  orders group by Order_Id order by Total_Profitt desc;"
        df = pd.read_sql_query(query, conn)
        
        df.to_csv("total_sel_price & profits.csv", index=False)
        
        print("Data successfully exported to query_result.csv")
        print(df.head())
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Data successfully exported to query_result.csv
#    Order_Id  Total_Selling_Price  Total_Profitt
# 0      2698             130406.4        21746.4
# 1      6827              84875.0        14875.0
# 2      9040             122141.5        12811.5
# 3      4278              61789.0         8309.0
# 4       166              62668.8         7868.8
